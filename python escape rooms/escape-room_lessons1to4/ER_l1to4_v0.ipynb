# %% [markdown]
# # Beginners Escape Room (Sessions 1–4)
#
# Skills:
# - Session 1: print, variables, math, sequencing, debugging
# - Session 2: data types + conversions
# - Session 3: decisions (if/else)
# - Session 4: loops
#
# **How to play**
# 1. Run cells from top to bottom.
# 2. For each lock, edit only the **Student Work** cell.
# 3. Run the **Check** cell to see if it unlocks.
#
# **Password:** unlock all 4 and you get the final word.

# %%
# Initialize game state
progress = []

def show_status():
    print("Fragments:", "".join(progress) if progress else "(none yet)")

print("Escape Room initialized")
show_status()

# %% [markdown]
# ## Lock 1 — Print sequencing
# Goal: build the output list `lines` in this exact order:
# 1. "Welcome, engineer!"
# 2. "Your mission: fix code to escape."
#
# **Student Work:** create the list `lines`.

# %%
# Student Work

# TODO: replace [] with the correct list in order
lines = []

print(lines)

# %%
# Check Lock 1
expected = ["Welcome, engineer!", "Your mission: fix code to escape."]
try:
    assert lines == expected, f"Incorrect order. Expected {expected} but got {lines}"
    if "C" not in progress:
        progress.append("C")
    print("Lock 1 unlocked. Fragment: C")
except Exception as e:
    print("Lock 1 still locked.")
    print(e)

show_status()

# %% [markdown]
# ## Lock 2 — Data types & conversion
# Goal: convert the string `num` to an integer and compute `double_num`.
#
# **Student Work:** set `double_num` to be twice `num`.

# %%
# Student Work
num = "4"  # string

# TODO: convert num and compute double_num
double_num = None

print(double_num)

# %%
# Check Lock 2
try:
    assert double_num == 8, f"Expected 8 but got {double_num}"
    if "O" not in progress:
        progress.append("O")
    print("Lock 2 unlocked. Fragment: O")
except Exception as e:
    print("Lock 2 still locked.")
    print(e)

show_status()

# %% [markdown]
# ## Lock 3 — Decisions
# Goal: build `even_or_odd` using an if statement.
# Expected:
# - If `n` is even → `even_or_odd = "Even"`
# - Otherwise → `even_or_odd = "Odd"`

# %%
# Student Work
n = 7

# TODO: set even_or_odd to the correct string
even_or_odd = None

print(even_or_odd)

# %%
# Check Lock 3
expected = "Odd"
try:
    assert even_or_odd == expected, f"Expected {expected} but got {even_or_odd}"
    if "D" not in progress:
        progress.append("D")
    print("Lock 3 unlocked. Fragment: D")
except Exception as e:
    print("Lock 3 still locked.")
    print(e)

show_status()

# %% [markdown]
# ## Lock 4 — Loop
# Goal: create a list `counting` containing the numbers 1 through 5, in order.

# %%
# Student Work

# TODO: use a loop to build counting = [1,2,3,4,5]
counting = []

print(counting)

# %%
# Check Lock 4
expected = [1, 2, 3, 4, 5]
try:
    assert counting == expected, f"Expected {expected} but got {counting}"
    if "E" not in progress:
        progress.append("E")
    print("Lock 4 unlocked. Fragment: E")
except Exception as e:
    print("Lock 4 still locked.")
    print(e)

show_status()

# %% [markdown]
# ## Escape
# Run this to see your final password.

# %%
final = "".join(progress)
print("Fragments collected:", final)
if final == "CODE":
    print("ESCAPE SUCCESSFUL: CODE")
else:
    print("Not yet! Keep unlocking.")
